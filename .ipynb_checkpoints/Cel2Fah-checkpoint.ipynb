# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
celsius    = [[-67.0], [-34.0], [0],  [34.0], [54.0], [67.0],   [100.0]]
fahrenheit = [[-88.6], [-29.2], [32], [93.2], [129.2], [152.6], [212.0]]

# %%
plt.scatter(celsius,fahrenheit, c='red', label='real')
plt.xlabel('celsius')
plt.ylabel('fahrenheit')
plt.legend()
plt.grid(True)
plt.title('real data')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
linear_regressor = LinearRegression()

# %%
linear_regressor.fit(celsius,fahrenheit)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
celsius_test = [[-50],[-30],[10],[20],[50],[70]]
fahrenheit_test = lr.predict(celsius_test)
print(fahrenheit_test)
# Out:
# [[-58.]
#  [-22.]
#  [ 50.]
#  [ 68.]
#  [122.]
#  [158.]]

# %%
plt.scatter(celsius,fahrenheit, c='red', label='real')
plt.scatter(celsius_test,fahrenheit_test, c='orange', label='predicted')
plt.xlabel('celsius')
plt.ylabel('fahrenheit')
plt.legend()
plt.grid(True)
plt.title('estimated vs real data')
plt.show()
